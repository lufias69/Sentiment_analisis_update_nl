# %%
from joblib import load
import ngram as ng
import pandas as pd

# %%
import os
import pymysql
import pymysql.cursors

# %%
host = os.getenv('localhost')
port = os.getenv('3306')
user = os.getenv('root')
password = os.getenv('')
database = os.getenv('test3')

conn = pymysql.connect(
    host=host,
    port=int(3306),
    user="root",
    passwd=password,
    db="test3",
    charset='utf8mb4')
cursor=conn.cursor()

# %%
# load the model from disk TF-idf
filename = 'model/tfdf_model_n_gram_NB.joblib'
tfidf = load(filename)

# load the model from disk naive bayes
filename = 'model/svm_model_n_gram_irham_NB.joblib'
SVM = load(filename)

# %%
proses = "lebih baik lagi"
proses = ng.ngram(proses)
tfidf_matrix_ng = tfidf.transform([proses])

prediksi_lx = SVM.predict(tfidf_matrix_ng.toarray())[0]
print("  "+proses)
print("<< N-Gram  : "+prediksi_lx+">>")
# Out:
#   lebih_baik lagi
# << N-Gram  : Positive>>

# %%
def prediksi(proses):
    proses = ng.ngram(proses)
    tfidf_matrix_ng = tfidf.transform([proses])
    prediksi_lx = SVM.predict(tfidf_matrix_ng.toarray())[0]
    return prediksi_lx

prediksi(proses)
# Out:
# 'Positive'

# %%
df = pd.read_sql_query("SELECT * FROM komentar_siswa_data_bersih;",conn)
df.head(10)
n_data = list()
id_ = df['id'].tolist()
asli = df['catatan_kuesioner'].tolist() #catatan_kuesioner harus diganti dengan data kotor/data belum masuk preprocessing
for i in df['catatan_kuesioner'].tolist():
    n_data.append(i.replace("[","").replace("]","").replace('"',"").replace(','," "))
n_data
# Out:
# ['jam tik banyak',
#  'kadang banyak teman rasa canggung bila cerita masalah pribadi',
#  'jam ajar tik tambah materi banyak',
#  'tingkat',
#  'tambah jam ajar tik akses wifi',
#  'ibu guru tik sinyal wifi kelas bu terima kasih',
#  'baik senang sekali mapel bk tik',
#  'sering sering jam kosong pakbiar ajar mandiri',
#  'lebih guna cara ajar tarik bosan',
#  'sering dibanyakin aktivitas lebih seru',
#  'ajar moga lebih asik greget bagas suatu masalah',
#  'ajar lebih tarik',
#  'seringsering nonton pak',
#  'lebih tarik cara menyajarnya pak',
#  'lebih banyak beri ajar cerita peristiwa kait islam',
#  'baik terlalu sering tinggal jam ajar',
#  'sering sering nonton film pak',
#  'saran pak amin musholanya cepat bangun pak biar bingung sholatnyaterimakasih',
#  'sering sering nonton film',
#  'pak sering sering pake lcd',
#  'saran ajar lebih baik',
#  'lebih banyak giat agama luar sekolah senang didik',
#  'lebih banyak main aktivitas bosan ajar',
#  'sipz',
#  'lebih banyak giat nyanyi luar sekolah',
#  'tetap semangat',
#  'kalo ulang jangan susah susah pak',
#  'terus semangat',
#  'ajar lebih variasi jadi asiik',
#  'kurang guna lcd jangan terlalu sering rangkum siswa blm pham ajar kmbli',
#  'terus kerja keras selalu',
#  'ajar lebih mudah murid biar mudeng pak',
#  'lebih perhati murid',
#  'lebih erti pikir siswa terang lebih jelas',
#  'baik tingkat',
#  'baik terus pakk',
#  'moga lebih mudengin depan pak terima kasih',
#  'pak ajar lebih pelan pak',
#  'baik kalo ajar lebih jelas kadang bahasa pak sigit kurang erti gamudeng',
#  'ajar game seling cegah bosan',
#  'saran ajar lebih baik jelas materi lebih rinci',
#  'semangat',
#  'lebih semangat ajar',
#  'seringsering ngelawak pakk',
#  'semangat pak',
#  'moga lebih banyak main',
#  'baik tingkat',
#  'sering renang pak',
#  'lebih sering buat ketawa pak',
#  'moga ajar selalu senang',
#  'saran ajar lebih baik',
#  'pak sering sering jam kosong dong patute pak nyong ngantuk kiye zzzzz',
#  'lebih sering pustaka',
#  'semangat pak',
#  'lebih banyak kerja kelompok ajar lebih jelas suara',
#  'tingkat',
#  'ganti kelompok lah pak',
#  'pak lebih sering lompok sama pus pak',
#  'saran lebih variasi cara ajar lebih bimbing siswa proses kbm',
#  'harap ibu lebih gali bakat semua siswa',
#  'lebih kenal murid ajar sabar',
#  'tingkat',
#  'jangan galak galak bu',
#  'lebih selaras mampu guru siswa selalu bimbing siswa alami kesul',
#  'harap ibu ajar penuh semangat senang',
#  'jangan banyak tugas hafal jangan banyak',
#  'tingkat',
#  'tugas banyak banget buu',
#  'lebih sesuai level soal beri ajar susun materi urut',
#  'teknik ajar lebih tarik mudah erti',
#  'tingkat',
#  'murah senyum dong bu',
#  'jangan cepet marah sensi bu',
#  'kalau ngajar jangan galak galak bu',
#  'lebih banyak aktivitas',
#  'tingkat',
#  'toleransi ditinggiin buu',
#  'ibu lebih sering canda bu jangan terlalu spaneng',
#  'baik kalo ajar main inisiatif lain kbm bosan',
#  'banyak banyakin jamkos pak hehehe',
#  'harap bapak ajar lebih semangat',
#  'tingkat',
#  'tambah asik buu',
#  'tingkat',
#  'tingkat',
#  'baik dibanyakkin beri materi cerita',
#  'lebih sering sharing',
#  'tetap jaga performa kerja',
#  'tingkat',
#  'lebih asik tarik',
#  'harap bapak lebih buat siswa rasa lebih nyaman',
#  'tingkat',
#  'harap bapak sampai materi lebih jelas',
#  'volume bicara lebih keras lebih jelas',
#  'semangat selalu pak',
#  'bicara baik bicara suara jelas keras dengar',
#  'suara lebih keras jelas',
#  'leih meri materi inovatif',
#  'lebih baik bila siswa punya paham agama baik',
#  'adakan macam giat erat hubung gurumurid antarmurid',
#  'tingkat',
#  'lebih asik',
#  'beberapa anak punya masalah mungkin ajak bicara personal bu terima kasih',
#  'kapan kenal ruang bk baik materi sampai media senang',
#  'tingkat',
#  'seringsering cerita buu',
#  'tingkat',
#  'cukup baik baik kurang baik kalo dibetulkanyangsabar',
#  'lebih baik laku kbm',
#  'pak kukuh ajar baik daan jelas',
#  'tahan pak tetap asik senang',
#  'tetap ramah pak kukuh',
#  'tetap semangat ajar lebih sabar',
#  'lebih responsif anak anak didik',
#  'makin asik ajar',
#  'tetap tahan bahkan kalau tingkat',
#  'lanjut pak',
#  'buat pak kukuh jangan suka baperngambek',
#  'maiin',
#  'tambah tegas jam olah raga beberapa siswa bantu',
#  'yappsippp',
#  'lebih guna teknik teknik mudah paham orang pandai olahraga',
#  'sabar ngajarin semua pak',
#  'buat pelaran lebih senang',
#  'banyak teori bukan praktek kalau ulang perlu teori',
#  'good job pak',
#  'tahan pak terus asik',
#  'jangan sedikitsedikit ngambek',
#  'ga pak',
#  'baik tambah ajar materi guna buku',
#  'lebih banyak materi main lebih sabar ajar',
#  'luar biasa',
#  'jangan sensitif pak sayang bapak lope lope',
#  'bagus',
#  'lebih sadar mampu situasi murid',
#  'bu may ajar sampai materi baik terkadang bikin ngantuk',
#  'lebih baik laku kbm',
#  'bu may the best',
#  'tetap ajar sabar bu',
#  'tahan jadi guru baik teladan perhati murid',
#  'kalau ngajar pelan pelan bu v',
#  'lebih senang ajar',
#  'lebih jelas kalau ajar murid mudah erti',
#  'kalo ngajar jangan terlalu cepet buu',
#  'maiin',
#  'kurang sikap pelit nlai dengar orang bu may orang pelit nilai',
#  'keren buuu keep easy going',
#  'lebih sering beri rumus cara cepat selesai soal soal',
#  'sabar ngajarin semua bu',
#  'lebih banyak cerita alam baru',
#  'lebih baik jelas ajar',
#  'banyak contoh soal ajar siswa lebih mudah paham',
#  'mudengi si mudengi bu jangan kecepetan v',
#  'kalau ajar jangan terlalu cepat',
#  'ajar kelas 11 tahun depan',
#  'lebi',
#  'luar biasa',
#  'bu may knp ibu lihat lebih pihak pinter plg tonjol',
#  'lebih sering masuk bu',
#  'lebih jelas ajar',
#  'lebih baik laku kbm',
#  'pak sigit njelasin jelas pak',
#  'beri ajar jelas mudah erti',
#  'ajar lebih perhati siswa kuasa materi',
#  'lebih perhati harga mampu anak lebih jelas ajar beri tugas',
#  'kalau buat soal gampang pak',
#  'paham siswa lebih baik',
#  'lebih jelas ajar cepat mudeng',
#  'pak ajar mohon terang bukan tulis buku',
#  'kalo ngejar lebih jelas jangan terlalu cepat',
#  'main',
#  'ajar jangan cepat',
#  'lebih sering beri jelas lamgsung kait dg cara mudah',
#  'sabar ngajarin semua pak',
#  'ajar lebih senang',
#  'moga depan lebih baik',
#  'pak sigit i love u dehhhh',
#  'soale jangan susah susah pak',
#  'beri penjelsan tugas lebih jelas',
#  'lebih pelan jelas',
#  'lebih keri sama murid',
#  'saran bapak sigit lebih jelas jelas lebih mudah erti',
#  'terimakasih pak',
#  'pak sigit tlg jelasin ajar dgn sabar n jelas dunk anak sma1 gak pinter kejap',
#  'latih lks bagus pak',
#  'lebih beri waktu banyak ulang tugas kelompok',
#  'lebih baik laku kbm',
#  'kalau ngajarin jangan cepet cepet bu lebih detail',
#  'moga bu guru ajar gantung ada emosi',
#  'lebih sabar lebih erti murid',
#  'sabar sabar bu',
#  'lebih tarik ajar',
#  'cukup mudah erti kalau tingkat',
#  'ibu sabar hadap murid murid ibu',
#  'lebih banyak beri contoh soal selesai beri tugas siswa',
#  'sangat baik',
#  'kurang suka mutung jadi guru selalu sabar gak mutung',
#  'lebih sabar guna cara simpel',
#  'sabar ngajarin bu',
#  'makin semangat ajar',
#  'moga lebih sabardan lebih baik kendali emosi',
#  'lebih baik depan bu',
#  'mandan kurang paham bu',
#  'moga selalu terus jelas ajar bu',
#  'lebih sering beri cara simple siswa bingung banyakny rumus',
#  'sabar bu',
#  'lebih sabar jelas jelas',
#  'lebih semangat ajar',
#  'terimakasih bu',
#  'bu sabar dunk bu sy jd takut klo pgn nanya trs jgn hny pihak pinter2 aja bu',
#  'latih dibanyakin bu',
#  'lebih baik laku kbm',
#  'sukses selalu pak',
#  'selalu ajar baik',
#  'baik jangan tiba tiba tunjuk siswa jawab tanya',
#  'lebih baik',
#  'bagus ajar tingkat pak',
#  'lebih semangat pak',
#  'lebih banyak beri contoh nyata hidup hari hari',
#  'seringsering senyum pak bapak manis',
#  'ajar kurang basa basi langsung materi',
#  'lebih beri materi kait masalah hari hari',
#  'sabar ngajarin semua pak',
#  'lebih variasi sampai materi',
#  'assalamualaikum pak aminnn banyakin cerita pak kalo ajar',
#  'tingkat cara ajar mungkin guna alat aga',
#  'tidaik',
#  'baik senang alahkan baik kalao lebih asyik',
#  'terimakasih pak',
#  'assalamuaalaikum paaaak d',
#  'sumber dibanyakin pak',
#  'banyak banyak nonton film bu',
#  'makin asik ibuuuuu',
#  'main',
#  'ajar enak mandan refreshing',
#  'lebih sering sampai materi',
#  'lebih baik laku kbm',
#  'sukses selalu bu',
#  'baik jawab tanya',
#  'baik banyak jelas materi detail',
#  'jangan presentasi terus bu wkkwkwk',
#  'baik jelas ajar murid erti jelas',
#  'lebih semangat',
#  'lebih sering jelas beri contoh',
#  'praktek dagang yuk',
#  'tambah rasa niat ajar tambah jelas ajar',
#  'lebih buat siswa aktif',
#  'sebaikmya lebih banyak jelas materi',
#  'lebih sering bagi tahu luar biasa',
#  'sangat suka nanii ilmu sangat luas',
#  'ngga mudeng bu',
#  'kalau ajar lebih banyak beri contoh masalah sering hadap siswa',
#  'banyakin kerja kelompok',
#  'lebih banyakin tugas kelompok tarik',
#  'terimakasih bu',
#  'ibu kok pinter wawas luas banget sih bu aku sayang ibukkkkkkkkkk',
#  'lebih banyak kerja kelompok bu',
#  'lebih baik laku kbm',
#  'ngajarnya lebih detai pak bikin soal jangan susah susah',
#  'ajar suara keras lebih jelas',
#  'baik lebih jelas materi jelas',
#  'lebih banyak catat beri contoh',
#  'sangat sabar',
#  'tambah niat ajar',
#  'lebih sering ajar kelas damping jelas pak',
#  'ajar suara keras',
#  'lebih kritis baik salah tugas siswa',
#  'lebih jelas',
#  'kalo ngajar jangan mlipir terus pak binggung apa lama bapak ajar',
#  'ajar mudah paham',
#  'kalau ajar sekalisekali beri contoh konkret bukan cari internet',
#  'bagus',
#  'lebih krits baik presentasi siswa',
#  'terimakasih pak',
#  'pak buat puisi pak sinar gelap sepoisepoi angin sore hari sy syang bapak',
#  'presentasi adain pak',
#  'lebih baik laku kbm',
#  'soal jangan susah susah bu',
#  'tetap jadi ibu guru erti',
#  'ibu variasi tambah',
#  'kalau buat soal ulang jangan terlalu susah',
#  'lebih seringsering praktek luar sekolah interaksi langsung masyarakat',
#  'ajar udah baik',
#  'lebih sering guna alat aga ajar',
#  'baik ajar jangan terlalu cepat',
#  'saluttt sama bu any selalu sabar euy',
#  'mudeng bu',
#  'lebih sering guna alat aga',
#  'waktu teliti banyakin bu',
#  'trimakasih bu',
#  'bu any sangat senang',
#  'teliti harus lebih banyak waktu bu',
#  'lebih peduli sama ndengerin sampai materi tambahin',
#  'lebih baik laku kbm',
#  'sabar terus pak',
#  'kejar lebih jelas keras suara pak',
#  'kalau ngomong keras pak',
#  'pak suara kerasin dikit',
#  'waktu ajar suara lebih keras pak',
#  'lebih sering praktek',
#  'suara kbm keras',
#  'ajar harap lebih tegas pak',
#  'ngga kedengeran kalo ngajar mungkin kotor telinga q banyak allah apa perlu aku beliin mix',
#  'maaf pakdalam ajar suara jelas pak',
#  'lebih keras suara kedengeran belakang',
#  'suara lebih dikerasin pak',
#  'saran bapak arif lebih keras suara ajar lebih jelas erti',
#  'mohon suara lebih keras',
#  'trimakasih pak',
#  'pak suara kerasin pak volume gak kedengeran sayang bapak',
#  'suara dikerasin pak',
#  'lebih baik laku kbm',
#  'sukses terus bu',
#  'tahan ramah bu',
#  'ibu tambah semangat bu',
#  'cara ajar baik ling cerita seharihari mudah erti',
#  'lebih sering praktek',
#  'baik bu',
#  'bu acnya lah bu kelas panas',
#  'banyakin cerita bu',
#  'terimakasih bu',
#  'bu ning x ipa 2 sayang ibu bangettttt',
#  'cerita dibanyakin bu',
#  'ngajarnya ditambahin canda pak',
#  'lebih baik laku kbm',
#  'baik bapak sering masuk kelas',
#  'tambah jam ajar',
#  'praktek luar sekolah',
#  'ayo pak semangat kembang budaya banyumasan',
#  'awas baju kena warna sintetis pakmalamnya panas pak awas kecipretan',
#  'tidak ada pak',
#  'terimakasih pak',
#  'pak anuhati hatimalamnya panas pak pagi dinginloh',
#  'lebih baik laku kbm',
#  'lebih harga kerja siswa bu',
#  'lebih sabar dlm ajar jangan paku 1 buku',
#  'lebih akrab siswa',
#  'praktek luar sekolah dong',
#  'semangat bu lebih sabar',
#  'lebih beri suatu ajar senang tegang',
#  'moga lebih sabarlebih jelasdan jangan paku satu buku',
#  'jangan galak galak ibuuu aku takutttt siahhhh',
#  'saran ibu erlina harga tugas siswa bu',
#  'lebih harga siswa kerja tugas',
#  'sampai materi denganlebih jelas tarik',
#  'terimakasih bu',
#  'mohon bersabarsy kepingin tanya mala jadi takut bu',
#  'calm bu',
#  'lebih baik laku kbm',
#  'lebih sering ajar alam',
#  'moga jadi guru teladan',
#  'pak lebih sering lab bio',
#  'tidak ada saran bapak bapak paling keren ajar',
#  'moga jadi lebih baik pak tetap semangat',
#  'lebih sering tunjuk orang jawab tanya',
#  '90 perfect',
#  'ajar gampang erti cepat hafal',
#  'terimakasih pak',
#  'moga ajar tdk bosan buat sisa semangat',
#  'sedikit suka keluar',
#  'lebih banyak nada diskusi',
#  'suka deh',
#  'lebih sering',
#  'terimakasih bu',
#  'bagus',
#  'guru tik nya baik ramah kira tidak ada saran',
#  'tingkat ajar',
#  'tambah jam ajar',
#  'seringsering ngajarin desain grafis buuuuu',
#  'sudqah baik',
#  'terimakasih bu',
#  'bu semua sayang ibuuuuuuuuu',
#  'tingkat jam tik',
#  'lebih baik laku kbm',
#  'kalau bikin soal ulhar ulang semester lain jangan susah susah bu hehehe',
#  'tetap sabar bimbing murid',
#  'ngantuk ajar ibu kalo tambah variasi sprti kerja',
#  'lebih banyak jelas materi beri contoh selesai',
#  'tambah video ajar',
#  'moga jadi lebih baik bu',
#  'lebih sering guna alat aga interaktif',
#  'bu',
#  'tambah waktu ajar tik',
#  'terimakasih bu',
#  'bu aku sayang bu titi',
#  'latih dibanyakin bu',
#  'kasih tau kalo mau seriusulangan canda murid sering blm siap',
#  'lebih baik laku kbm',
#  'lebih sering jelas materi pak',
#  'moga tambah maju pak tetap akrab sama muridmurid',
#  'tetap jadi guru erti',
#  'baik lebih jelas materi',
#  'perfect pak',
#  'tugas jangan proyek proyek terus',
#  'jangan terlalu sering jamkos',
#  'bapak keren aku suka gaya bapakk love you pak',
#  'pak bapak baik lebih perhati kesulitan2 siswa pak',
#  'kayak bapak jd guru bakat jg jadi lenong dehh siapa tau hasil kaya sule pak',
#  'lebih buat asyik',
#  'terimakasih pak',
#  'cara ajar pak muji sangat senang bosan',
#  'tugas',
#  'lebih sabar bu',
#  'baik lebih sabar hadap siswa',
#  'lebih sabar dengar jelas siswa',
#  'lebih santai bu rangin ngomelnya anakanak punya masalah rumah',
#  'moga jadi lebih baik ajar jadi lebih sabar',
#  'lebih sabardalam rencana suatu acara lebih perhati mampu siswa',
#  'terimakasih bu',
#  'maaf bu kalau banyak salah manusia biasa tdk ibu marah',
#  'waktu deadline nya jelas bu',
#  'seringsering senyum bu',
#  'selalu tanya materi selesai anak anak mudeng apa',
#  'ajar beri hibur antuk',
#  'bicara bu erna harap lebih pelan jelas',
#  'moga isi kuisioner ajar biologi jadi bosan',
#  'baik ajar lebih kreatif buat game kena bab ajar',
#  'jangan terlalu banyak guna nama ilmiah tahu bu',
#  'moga lebih baik ajar',
#  'moga lebih baik',
#  'baik sedang sampai materi jelas',
#  'pembelajarn bio tdk ngantuk trmksh',
#  'ajar beri inovasi sampai materi',
#  'baik bicara lebih jelas',
#  'ibu guru ajar harap lebih jelas sampai materi terima kasih',
#  'cara ajar lebih jelas lebih mudah erti',
#  'makasih bu',
#  'ajar lebih tarik murid bosan ajar',
#  'bubanyakin praktek lab',
#  'lama ajar lebih mudengin makin sabar ajar bu',
#  'bu murid kurang lihai ajar biologi',
#  'buat soal lebih kerucut materi',
#  'terimakasih',
#  'ajar biologi antuk mungkin kbm beri wktu merefresh',
#  'jangan terlalu banyak materi bu buat rangkum singkat',
#  'saran bu erna jelas runtut bahasa lebih simple',
#  'gaya bicara kurang jelas terlalu cepat moga waktu bu erna ajar lebih',
#  'semangat bu',
#  'baik bu erna lebuih guna bahasamimik muda paham',
#  'lebih asik bu ngajarnya kadang ngantuk',
#  'jaga sehat bu jangan marahmarah kasi baby nyaaa',
#  'bagusterimaksih ajar bu',
#  'minnta saran ajar sejarah bosan',
#  'materi lebih kerucut bu biar terlalu susah',
#  'cara ajar lebih kreatif bosan buat game',
#  'semangat terus bu',
#  'moga lebih baik ajar',
#  'moga lebih baik',
#  'cara ajar buat tarik',
#  'sukses terus bu anis',
#  'bagus bu',
#  'semangat terus bu sukses selalu',
#  'bu anis ajar semangat',
#  'baik lebih sering kasih tugas lebih banyak latih',
#  'baik bu',
#  'ajar lebih tarik variatif cara ajar',
#  'bagus',
#  'bujang kasih tugas banyak',
#  'ibu buat semangat y',
#  'terimakasih ibu anissukses terus moga lancar lahir',
#  'bu meski masa lalu sakit ingat sejarah kandung banyak manfaat',
#  'moga lebih baik',
#  'lebih baik ajar',
#  'terus inovasi ga bosen mapel sejarah bu',
#  'semangat terus bu ngajarnya sabar kalo ngadepin anak nakal buu',
#  'terus semangat bu',
#  'lebih banyak cerita kisah2 dlm sejarah lebih paham',
#  'bagus bu',
#  'harga kerja keras kerja bu makasih',
#  'bu astuti wali kelas keren',
#  'jangan baper bu',
#  'moga hubung murid makin baik',
#  'murid lebih perhati harap ibu lebih akrab teman teman',
#  'moga depan ajar mat wajib jadi lebih mudengin jangan sering ngambek bu',
#  'lebih sabar',
#  'percaya bu ajar jadi pribadi lebih baik jadi santai bu',
#  'moga selalu senang ajar kelas x mipa 3',
#  'smoga lebih baik',
#  'ajar lebih sabar',
#  'smg depan lebih baik bu astuti',
#  'jangan baperan bu hehe',
#  'baik jangan banyak pr tingkat cara ajar',
#  'baik ajar jangan terlalu cepat',
#  'makasih bu',
#  'hadist barangsiapa susah orang susah akhirat nant',
#  'moga buat kelas jadi makin baik',
#  '1000 cerita indah 1000 soal gundah',
#  'lebih sesuai soal waktu beri',
#  'beri tugas jangan banyakbanyak bu',
#  'lebih sabar didik bu',
#  'ajar hendak ibu astuti lebih sabar jelas baik',
#  'ajar ibu ikan mudah erti mohon dipertahankanbu terimakasih',
#  'baik jangan terlalu cepat beri soal siswa paham',
#  'jangan sering marah bu',
#  'bagusterimaksih ajar bu',
#  'moga ibu lebih sabar erti jangan terlalu kaku murid',
#  'jangan galak galak bu',
#  'lebih sabar',
#  'mungkin coba ajar versi lebih tarik bu',
#  'moga lebih baik ajar',
#  'smoga lebih baik',
#  'sabar ajar',
#  'bu endang tahan bu baik terima kasih',
#  'terimakasih ajar cukup baik ajar',
#  'baik jangan cepat singgung jangan suka berat',
#  'lebih sering beri contoh gerakangerakan tari',
#  'lebih baik tidak ada pagelaran',
#  'moga nilai naik',
#  'kalaupun aku lihai ibu tari',
#  'lebih erti mampu siswa',
#  'jangan galak galak',
#  'moga adik kelas kaget ada pagelaran',
#  'lebih inovasi bu',
#  'bu endang jangan galak galak yaaaa banyakin senyum jangan ngasih tugas susah2',
#  'bu endang mohon tahan baik terimakasih',
#  'baik jangan beri tugas sita waktu siswakarena siswa banyak perlu',
#  'jangan galakgalak bu',
#  'bagusterimaksih ajar pak',
#  'tetap semangat sabar hadap siswa kurang ajar olahraga',
#  'terus senang biasa paak',
#  'moga lebih baik ajar',
#  'baik',
#  'ajar asik sih kadang gabut',
#  'bagus bu terimakasih atas semua',
#  'jarang jamkos',
#  'lebih sering refreshingnya',
#  'trima kasih pak',
#  'pak sering sering olahraga asik',
#  'lawa lucu pak',
#  'moga nilai lebih naik pak',
#  'semangat terus',
#  'moga olahraga tambah asik',
#  'moga jadi lebih baik ajar',
#  'makin inovatif pak',
#  'pak kukuh da best lahh pokok',
#  'baik lebih mudah hubung',
#  'bagus pak',
#  'bagusterimaksih ajar bu',
#  'jangan lupa istirahat bu sering sering kasi tips sukses bu',
#  'moga lebih baik ajar',
#  'smoga lebih baik',
#  'ibu guruu favorite sayaaa',
#  'lebih sering beri fcontoh susah siswa susah',
#  'makasih bu',
#  'beri soal terlalu sulit',
#  'makin senang',
#  'bunaikan niali dong',
#  'guru baik smansa y',
#  'bu mungkin rumah terlalu jauh ilmu bangan jalan',
#  'jangan jamkos lagikimia penting',
#  'semangat bu ajar',
#  'bu may kalo ngajar enak banget jadi ngga komentar',
#  'bikin soal jangan terlalu suli bu',
#  'baik kalau ulang soal jangan susah bu',
#  'makin asik ajar',
#  'bagusterimaksih ajar bu',
#  'guna bahasa lebih erti bu kadang bahasa ekonomi kurang sering dengar',
#  'smoga lebih baik',
#  'bagus bu terimakasih atas semua',
#  'seringsering beri rangkum materi ajar mudah',
#  'baik pak',
#  'jangan buat siswa antuk',
#  'sisip nama doa doa doa anak didik moga masuk stan',
#  'terus semangat',
#  'terkadang murid perhati guru bu',
#  'bu nan ajar sangat enak lalau sering main hp kletika ajar langsung',
#  'baik kbm isi giat seru ngantuk',
#  'bagus',
#  'bagusterimaksih ajar pak',
#  'moga ga ngantukin',
#  'asik sekali apabila sifat pak eko terus pak',
#  'smoga lebih baik',
#  'bagus terimakasih atas semua',
#  'baik lebih sering jelas siswa paham',
#  'kurang teknologi pak',
#  'bagus',
#  'sering sering jamkos pak',
#  'mantap pak',
#  'pak sedang kenan ajar',
#  'terus semangat',
#  'jangan pensiun dulu',
#  'sangatmenyenangkan ajar bapak lebih baik lg ajar',
#  'kalo ngajar jangan limpah murid pak butuh jelas',
#  'kebanyaken tugas kelompk pak rangin dikit laaaa',
#  'baik kbm isi giat seru ngantuk',
#  'baik pak eko lebih semangat ajar',
#  'bagusterimaksih ajar pak',
#  'pak bapak suara dikarin yaa makasih pak',
#  'pak arif ajar suara lebih keras semua siswa dengar jelas',
#  'moga ajar lebih baik',
#  'suara kerasin semua siswa perhati pak arif jadi anak anak ramai sendiri',
#  'bagus terimakasih atas semua',
#  'baik bicara keras semangat teruuus paaak sukses selalu pak',
#  'lebih baik volume suara kerasin lebih jelas',
#  'kalo ajar suara kerasin',
#  'kalo ulang jangan pake hanacaraka',
#  'suara kurang keras pak',
#  'pak arif is the best pokoke yaaaa pak p',
#  'sampun apik pis pak gol mulang y',
#  'maafsuarannya tolomg rasi pak',
#  'lebih kers',
#  'baik',
#  'baik kbm isi giat seru ngantuk',
#  'bagusterimaksih ajar bu',
#  'moga lebih baik ajar',
#  'bagus terimakasih atas semua',
#  'seringsering buat rangkum materi siswa',
#  'trimakasih bu',
#  'makin senang',
#  'pasal pasal orang buat jahat',
#  'pasal laku orangorang kriminal jadi jadi orang baik kurang faedah',
#  'saran jangan terlalu banyak bahas luar materi bu',
#  'bu ning ajar bagusnamun perlu isi dgn giat senang',
#  'bagus terimakasih atas semua',
#  'lebih jelas sampai materi',
#  'tidakterlalu bahasa inggris',
#  'ajar kreatif pak',
#  'mungkin lahir jerman jadi terlalu mahir bahasa inggris',
#  'sipp',
#  'sangat senang ajar sama pak muji',
#  'inovatif pak',
#  'senang sekali ikut ajar bapak tahan humor nya pak',
#  'baik cara ajar isi giat kebih senang ngantuk',
#  'jangan suka nunjuk nunjuk anak bu',
#  'ngga tau sering ngantk kalo lg ajar ibu',
#  'jangan suka nunjuknunjuk anak bu',
#  'lebih jelas sampai materi lebih banyak rangkum',
#  'lebih hibur ajar',
#  'ajar lebih baik',
#  'jangan buat antuk',
#  'perilaku baik cukup baur masyarakat perlu belit belit',
#  'jangan motong jam pelajharan dong bu hehe',
#  'baik cara ajar isi giat lebih senang ngantuk',
#  'dibanyakin nonton film nabi muhammad saw',
#  'doa banyak',
#  'bapak orang sangat butuh jadi akhlak siswa smansa puji',
#  'saran deh pak',
#  'baik cara ajar isi giat lebih senang ngantuk',
#  'tahan pak',
#  'bagus terimakasih atas semua',
#  'lebih baik ada diskusi kelompok',
#  'lebih hibur ajar',
#  'good',
#  'tahan pak',
#  'bagus',
#  'cukup baik pak',
#  'lebih mudengin ngajarnya pak biar lebih paham',
#  'jadi lebih baik',
#  'kalau ngasih tugas jangan banyak pak',
#  'jangan terlalu susah beri soalsoal',
#  'kurang tugas pak',
#  'makin tarik',
#  'jangan sukamarah',
#  'makin sabar ajar pak maaf suka bikin kesel wanita kagum bapak x mia 3',
#  'kamu kecimpung kamu suka kamu dapat bahagia hakiki',
#  'moga lebih baik ajar',
#  'semangat terus pak',
#  'baik cara ajar isi giat lebih senang ngantuk',
#  'baik kalau ajar materi jelas langsung tulis jangan baca ppt',
#  'ruang batik kurang nyaman pak',
#  'moga usaha batik makin baik pak',
#  'bapak emang paling top v',
#  'good job pak',
#  'tahan pak',
#  'moga lebih baik ajar',
#  'smoga lebih baik',
#  'kalo bikin soal ulang jangan susah susah pak',
#  'lebih baik beri materi lebih detail batik',
#  'jangan jam kosong pak',
#  'diri usaha batik bukan mustahil',
#  'bapak emang paling top',
#  'pak kalo sedang proses ajar ajar jangan main main asap',
#  'tahan pak',
#  'kurang rokok pak',
#  'baik pak joko beri variasi giat kbm bosan',
#  'baik teori batik jelas',
#  'mbatiknya sering sering pakkkkk',
#  'cara megajarnya kurang bu banyak temanteman antuk',
#  'kalau sedang kbm jelas murid murid mudeng bu jangan cuma suru baca buku',
#  'lebih sering mbahas tipe tipe soal beda bu biar jadi mudeng',
#  'moga lebih baik ajar',
#  'moga jadi lebih baik',
#  'jangan terlalu cepat buu ngga mudeng',
#  'jangan terlalu cepat ajar',
#  'kalo ajar diri bu',
#  'tidur rupa suatu proses tumbuh ganggu tumbuh normal',
#  'kalo ajar diri jangan duduk terus kalo njelasin mudenginjadi murid gaperlu les',
#  'bu tidur ajar fisika biar sedang lanjut mimpi malam',
#  'mau ajar tdk duduk',
#  'salah satu guru favorit',
#  'lebik baik bu jelas materi',
#  'baik cara ajar isi giat lebih senang ngantuk',
#  'makin baik cara ajar',
#  'baik ajar lebih senang lihat vidio',
#  'sampai materi suara kurang keras',
#  'jangan telat',
#  'jangan lama ajar bu bosen',
#  'ibu kurang semangat',
#  'moga jadi lebih baik',
#  'jangan sering jam kosong bu',
#  'baik cara ajar isi giat lebih senang ngantuk',
#  'baik ibu beri bimbing materi tarik senang sprt tayang vidio',
#  'banyak komputer kadang kadang kerja baik baik',
#  'ajar tik lebih ringin bu misal 2kali bulan',
#  'komputer sambung internet baik betul',
#  'lebih banyak kasih materi tentan komputer',
#  'makasih bu',
#  'sering sering lab bu',
#  'terus inovasi mkurid mudah ungkap masalah canggung',
#  'baik bu anni beri variasi pd giat kbm lebih seru kmb nya',
#  'baik wifi sekolah baik sambung semua komputer',
#  'moga depan lebih baik cara sampai materi jangan terlalu cepat',
#  'ibu baik beri ajar lebih tingkat bu',
#  'nice',
#  'good',
#  'menawi ngajar ampun kecepeten nggih bu',
#  'sampai materi lebih jelas',
#  'ajar lebih detail',
#  'jangan jutek lebih ramah kalau ngajar lebih santai',
#  'harap ibu ajar lebih semangat',
#  'semangat bu',
#  'sabar bu kalau ribut hehehe',
#  'jangan jutek cuek lebih ramah sama jangan bikin spanneng kelas murid jadi ngga nyaman kelas',
#  'lebih sabar ajar',
#  'sabar bu hehe',
#  'baik bu astuti lebih ramah lebih perhati murid',
#  'siswa tanya lewat media sosial balas terimakasih',
#  'mampu siswa harap lebih perhati bahas soal soal sulit jangan lewat',
#  'tidak ada saran',
#  'lebih baik sampai materi',
#  'tambah sabar bu',
#  'baik ajar lebih jelas siswa siswi lebih mudah paham',
#  'harap ibu beri ajar lebih baik',
#  'moga ajar matematika asa lebih senang',
#  'saran nya bu lebih sabar',
#  'lebih baik sampai ajar',
#  'muncul sedikit toleransi siswa tambah ceria ajar',
#  'tambah sabar bu biar makin cantikkk',
#  'tambah cantik bu',
#  'sampai materi jangan terlalu cepat moga depan lebih baik',
#  'ibu baik buat metode ajar lebih tarik perhati siswa tarik',
#  'banyakin latih soalsoal nya buu',
#  'terimakasih atas bimbinganya',
#  'menawi nerangaken materi ampun kecepeten nggih bu',
#  'ajar baik lebih erti mampu siswa proses buah materi',
#  'metode lebih tarik soal kalo ajar ngantukin',
#  'ajar buat lebih senang',
#  'harap ibu lebih pelan beri ajar rasa ibu m',
#  'kalau ajar jangan terlalu datar bu',
#  'ajar lebih buat asyik bu',
#  'ajar usaha buat siswa antuk bu',
#  'kalau ajar kasih giat ngantuk',
#  'baik bu sri lestari lebih variasi ajar bosan',
#  'hebat',
#  'lebih perhati mampu peajar tenatang materi sampai',
#  'lebih jelas aja bu',
#  'lebih baik sampai ajar',
#  'moga antuk ajar',
#  'baik cara ajar lebih ubah siswa siswi lebih erti sampai',
#  'harap ibu lebih dekat diri siswa siwi',
#  'moga ajar fisika lebih asyik guna alat aga kelompok',
#  'jangan terlalu spaneng',
#  'tetap semangat ajar bu',
#  'jangan terlalu serius ajar',
#  'sabar bu',
#  'sampai materi moga depan lebih baik',
#  'baik sampai materi ajar lebih jelas bicara',
#  'good job bu b',
#  'menawi nerangaken materi ampun kecepeten nggih bu',
#  'moga materi sukar jelas baik lebih mudah paham',
#  'metode ajar lebih kreatif karna biologi rumit mudah paham',
#  'ajar lebih senang jadi nyaman ajar',
#  'baik ibu beri ajar lebih inovatif ajar bosan',
#  'kalau bicara jangan terlalu cepat',
#  'lebih sabar bu maklum kalau buat salah',
#  'ajar ucap jelas bu',
#  'baik bu erna lebih jelas terang ajar',
#  'kalau bicara depan jangan terlalu cepat',
#  'bahas uji kompetensi',
#  'bedah lg busaya ikut',
#  'lebih jelas sampai materi',
#  'buat lebih senang',
#  'baik ajar lafal kata sedikit jelas',
#  'baik',
#  'moga ajar biologi lebih asyik ada praktek laboraturium',
#  'jangan terlalu spaneng',
#  'lebih sabar sampai materi',
#  'bagus',
#  'muncul muka senyum selalu bu',
#  'praktik yuh bu',
#  'moga depan lebih baik',
#  'baik ajar lebih tingkat dalam materi',
#  'good job pak b',
#  'menawi ngajar pun tambah fariasi supados mboten mboseni lan ngantuki',
#  'kalau ajar jelas nya lebih banyakin jangan suruh menyetabilo',
#  'moga lebih sering beri materi pancing kerjasama kelompok',
#  'metode ajar lebh tarik',
#  'lebih seru ngajarnya',
#  'baik lebih semangat ajar lebih brinovatif daam ajar',
#  'lebih semangat ngajarnya pak',
#  'usaha buat suasana ajar terlalu bosan pak',
#  'jangan pergi2 terus pak',
#  'kalo ngajar jangan lupa senyum pak',
#  'baik pak sam lebih perhati murid',
#  'jangan lupa senyum pak jangan sering tinggal jam ajar',
#  'jelas materi lebih jelas',
#  'bahas materi ajar cara metode',
#  'lebih semangat sampai materi',
#  'buat lebih nyaman',
#  'tingkat',
#  'harap bapak beri lebih ajar ajar',
#  'moga ajar sosiologi tambah praktik bosan ajar kelas terus',
#  'jangan terlalu spaneng',
#  'lebih semangat ajar',
#  'jangan php pak',
#  'jelas jangan terlalu textbook',
#  'baik ajar selalu praktek tari isi materi pembelajara',
#  'nice',
#  'tetap semangat sabar',
#  'moga seni budaya lebih variasi',
#  'lebih akrab murid',
#  'lebih sabar bimbing',
#  'baik materi banyak lebih inovatif',
#  'semangat bu',
#  'kalau beri tugas pertimbangakan tugas punya bu',
#  'lebih sabar erti bu tugas kelompok lebih sulit sama gerak',
#  'lebih sabar erti bu',
#  'lebih sabar',
#  'baik bu endang lebih perhati sibuk murid',
#  'lebih baik sampai materi',
#  'moga bu endang lebih sabar hadap murid murid',
#  'baik paham ada murid murid',
#  'harap ibu lebih dekat diri siswa',
#  'moga ajar seni budaya lebih pengertain lebih siap murid',
#  'jangan terlalu spaneng',
#  'lebih sabar ajar',
#  'bagus',
#  'sabar bu',
#  'tugas mohon ringan dukung giat siswa non akademik',
#  'moga depan lebih baik',
#  'baik tingkat',
#  'tidak ada saran nice buuuu',
#  'semangat ibu',
#  'lebih semangat ngajarnya',
#  'baik depan lebih banyak ajar sifat diskusi',
#  'metode pembelejarannya lebih variatif',
#  'semangat terus ngajar bu',
#  'baik ibu beri ajar lebih semangat',
#  'semangat',
#  'lebih baik bu',
#  'semangat sabar ngajar 10 mia 5 bu',
#  'lebih tegas bu',
#  'tambah semangat ngajarnya bu',
#  'tidak ada bu',
#  'lebih baik ajar',
#  'makin baik bu ros',
#  'tingkat bu',
#  'sangat baik lebih baik',
#  'moga ajar bahasa indonesia tambah praktek bosan lebih asyik',
#  'jangan terlalu spaneng',
#  'semangat selalu bu',
#  'bagus bu',
#  'debat bu',
#  'good',
#  'semangat kimiaaa',
#  'harap kalua jelas bicara jelas papan tulisa lebih jelas',
#  'moga sampai materi lebih jelas',
#  'dijelasin bab detail biar paham',
#  'lebih sabar ajar',
#  'baik ajar lebih tenang',
#  'ngajar nya pelan pelan bu jangan kecepetan semangat bu',
#  'kalau jelas jangan terlalu cepat pasti paham baru lanjut bu',
#  'kalau ajar lebih banyak beri materi bu jangan langsung kasih soal materi',
#  'jelas materi lebih jelas beri tugas uh lebih kira bu',
#  'lebih sabar hadap bu hehe',
#  'baik bu uji lebih jelas terang',
#  'aeda',
#  'sampai materi jelas jangan langsung masuk soal materi jelas',
#  'moga lebih erti kimia',
#  'baik jelas sampai materi lebih tingkat',
#  'harap ibu lebih dekat diri siswa maupun siswi',
#  'moga ajar kimia lebih asyik ada praktek labkimia',
#  'semangat terus',
#  'jangan kecepetan bu',
#  'jiika terang toloong lebih jelas',
#  'jangan seringsering jam kosong',
#  'semangat ppkn',
#  'terima kasih bu',
#  'baik batas ajar kelompok',
#  'metode ajar lebih variatif lafgi',
#  'semangat terus bu selalu ramah',
#  'sabar ibu',
#  'lebih tingkat',
#  'lebih sabar bu',
#  'lebih jelas dalam',
#  'terima kasih bu',
#  'moga ajar pkn terus senang',
#  'tingkat bu',
#  'moga ajar ppkn lebih tarik ada praktik tinjau masalah perintah',
#  'semangat terus',
#  'good job buuu',
#  'baik materi sampai lebih praktis',
#  'metode lebih variatif',
#  'lebih sabar ajar lebih ramah',
#  'sabar bu kalau ricuh',
#  'jelas ajar buat lebih mudah kadang bingung kalo jelas terlalu kompleks',
#  'terus semangat ngajarnya bu',
#  'moga terus senang sabar bu',
#  'tingkat bu',
#  'moga ajar sejarah lebih asyik ada praktik',
#  'jangan terlalu spaneng',
#  'salam olahragaaa',
#  'lebih sabar hadap perilaku siswa',
#  'moga makin baik',
#  'lebih seru ngajarnya',
#  'semangat pak',
#  'lebih tingkat',
#  'tambah semangat ngajarnya pak',
#  'pak kukuh sangat baik ajar',
#  'banyakin giat basket pak',
#  'moga tambah senang',
#  'bagus tingkat pak',
#  'semangat terus',
#  'tetap semangat pak',
#  'baik tetap tingkat',
#  'semanggattttt',
#  'terimakasih pak',
#  'semangat pak',
#  'tingkat',
#  'lebih jelas materi',
#  'mantap pak',
#  'tingkat pak',
#  'harap lebih dekat murid kelas',
#  'pak mohon ac 10 mia 5 baik',
#  'semangat pakkkk',
#  'ajar sesuai materi',
#  'lebih jelas materi',
#  'can you give us time with native speaker',
#  'tingkatkank pak',
#  'ibu ajar baik',
#  'kerja ibu didik ajar kamimenurut sangat baik',
#  'semangat bu bk sangat bantu saya',
#  'lebih semangat ajar selalu sabar ajar',
#  'lebih dekat murid murid nya',
#  'moga depan makin bantu menyelesain masalah soal siswa',
#  'giat ajar baik lebih buat santai',
#  'banyakin giat ajar bu ngantuk',
#  'semangat buu materi bk nya sangat membantuy',
#  'giat ajar tambah terlalu banyak materi jatuh bosan antuk',
#  'siswa da',
#  'lebih sering cerita ptn sekolahsekolah ikat dinas',
#  'lebih bimbing lebih baik',
#  'jam ajar bk tambah',
#  'sayasemoga ajak ruang bk lihat prestasinilai kakak kelas',
#  'saran kalau ajar jangan terlalu serius',
#  'banyak hibur serius ajar',
#  'sehat selalu bu',
#  'ibu ajar baik',
#  'kerja ibu beri layan tik sangat baik efektif',
#  'jam ajar bktik mungkin panjang',
#  'baik',
#  'baik ajar lebih interaktif lag siswa',
#  'tik ajar enakditambah jam',
#  'leboh lama bk tik nya karna bk tik sangat bantu laku tugas hari hari',
#  'tik ajar senang dibanyakin jam ajar tik nya',
#  'ajar tik jangan laku bulan 1x bulan 2x',
#  'jam ajar bktik banyak',
#  'ajar tik sering lebih guna kemudian hari',
#  'giat ajar baik lebih perhati mampu siswa',
#  'jam ajar bktik banyak',
#  'jam tik tambah',
#  'kalo bktik bulan 2 kali ajar teknologikomputer lebih',
#  'saran lebih tepat waktu kalau ajar',
#  'bk tik sangat bantu sekali',
#  'banyak hibur serius ajar',
#  'sehat selalu bu',
#  'ajar lebih jelas bicara',
#  'riddle maam',
#  'ajar lebih semangat bu',
#  'lebih tegas bu',
#  'hebatt',
#  'baik tingkat jelas bicara',
#  'ayo aktif',
#  'tetap sabar ajar',
#  'semangat pakk',
#  'kalau ajar suara harap keras duduk belakang suara kedengeran',
#  'suara ajar lebih jelas pak semangat pak',
#  'kalau ajar keras suara pak',
#  'hebat',
#  'ajar suara lebih keras',
#  'tambah sabar pakkk',
#  'tetap sabar',
#  'lebih jelas sampai materi',
#  'vektoorrrr',
#  'kalau ajar jangan ngebutngebut pak',
#  'saat ajar bantu siswa materi bingung',
#  'beri materi soalsoal banyak jangan ulang hari dadak',
#  'lebih jelas sampai materi',
#  'tetap sabar',
#  'moga jelas materi lebih jelas',
#  ...]

# %%
pred_list = list()
for p, ix in zip(n_data, id_):
    hasil = prediksi(p)
    pred_list.append(hasil)
#     print(hasil)
    sql = "UPDATE komentar_siswa_data_bersih SET class_prediksi = '%s' WHERE `id` = '%s'" % (hasil, ix)
    print(hasil, ix)
    try:
        cursor.execute(sql)
        conn.commit()
    except:
        conn.rollback()

# %%
dictt={
    'id':id_,
    "label prediksi":pred_list,
    "komentar":n_data,
    "komentar_asli":asli,
}
df=pd.DataFrame.from_dict(dictt)
df.to_excel("hasil_prediksi.xlsx")

# %%
from sklearn.metrics import classification_report
y_true = pred_list
y_pred = df['class'].tolist()
target_names = ['Negative', 'Positive']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.86      0.82      0.84      1741
#     Positive       0.87      0.90      0.88      2344
#
#     accuracy                           0.86      4085
#    macro avg       0.86      0.86      0.86      4085
# weighted avg       0.86      0.86      0.86      4085
